# %% [markdown]
# <div style = 'background-color: #6482AD; text-align:center; padding: 10px; color:#F5EDED'>
#     <h1> Logistic Regression</h1>
#     <h2><a href = 'https://www.linkedin.com/in/ahmedsharaf9/' style = "text-decoration: none; color: #F5EDED">Ahmed Sharaf</a></h2>
# </div>   </ul>
# </div>

# %% [markdown]
# <div style = 'background-color: #6482AD; text-align:center; padding: 10px; color:#F5EDED'>
#     <h2>Import Libraries</h2>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# <div style = 'background-color: #6482AD; text-align:center; padding: 10px; color:#F5EDED'>
#     <h2>Create Data</h2>
# </div>

# %%
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=1000, n_features=10, n_classes=2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %% [markdown]
# <div style = 'background-color: #6482AD; text-align:center; padding: 10px; color:#F5EDED'>
#     <h2>Logistic Model</h2>
# </div>

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
## predicr
y_pred = model.predict(X_test)

# %%
## Metrics Of Model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print(f'Accuracy = {accuracy_score(y_test, y_pred)}')
print('#'*20)
print('Confusion Matrix : ')
print(confusion_matrix(y_test, y_pred))
print('#'*20)
print('Classification Report : ')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy = 0.908
# ####################
# Confusion Matrix :
# [[124  14]
#  [  9 103]]
# ####################
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92       138
#            1       0.88      0.92      0.90       112
#
#     accuracy                           0.91       250
#    macro avg       0.91      0.91      0.91       250
# weighted avg       0.91      0.91      0.91       250

# %% [markdown]
# <div style = 'background-color: #6482AD; text-align:center; padding: 10px; color:#F5EDED'>
#     <h2>Logistic Model With GridSearch And Cross Validation</h2>
# </div>

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
parameters = {
    'penalty': ['l1', 'l2', 'elasticnet'],
    'C': [100, 10, 1.0, 0.1, 0.01],
    'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
}
grid = GridSearchCV(LogisticRegression(), param_grid=parameters, cv = StratifiedKFold(), n_jobs=-1)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [100, 10, 1.0, 0.1, 0.01],
#                          'penalty': ['l1', 'l2', 'elasticnet'],
#                          'solver': ['lbfgs', 'liblinear', 'newton-cg',
#                                     'newton-cholesky', 'sag', 'saga']})

# %%
grid.best_params_
# Out:
# {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}

# %%
grid.best_score_
# Out:
# 0.932

# %%
## Metrics Of Model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
y_pred = grid.predict(X_test)
print(f'Accuracy = {accuracy_score(y_test, y_pred)}')
print('#'*20)
print('Confusion Matrix : ')
print(confusion_matrix(y_test, y_pred))
print('#'*20)
print('Classification Report : ')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy = 0.916
# ####################
# Confusion Matrix :
# [[126  12]
#  [  9 103]]
# ####################
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       138
#            1       0.90      0.92      0.91       112
#
#     accuracy                           0.92       250
#    macro avg       0.91      0.92      0.92       250
# weighted avg       0.92      0.92      0.92       250

# %% [markdown]
# <div style = 'background-color: #6482AD; text-align:center; padding: 10px; color:#F5EDED'>
#     <h2>Logistic Model With RandomizedSearch And Cross Validation</h2>
# </div>

# %%
from sklearn.model_selection import RandomizedSearchCV
randomcv = RandomizedSearchCV(LogisticRegression(), param_distributions=parameters, cv = 5, n_jobs=-1)
randomcv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#                    param_distributions={'C': [100, 10, 1.0, 0.1, 0.01],
#                                         'penalty': ['l1', 'l2', 'elasticnet'],
#                                         'solver': ['lbfgs', 'liblinear',
#                                                    'newton-cg',
#                                                    'newton-cholesky', 'sag',
#                                                    'saga']})

# %%
randomcv.best_params_
# Out:
# {'solver': 'saga', 'penalty': 'l1', 'C': 0.1}

# %%
randomcv.best_score_
# Out:
# 0.9279999999999999

# %%
## Metrics Of Model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
y_pred = randomcv.predict(X_test)
print(f'Accuracy = {accuracy_score(y_test, y_pred)}')
print('#'*20)
print('Confusion Matrix : ')
print(confusion_matrix(y_test, y_pred))
print('#'*20)
print('Classification Report : ')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy = 0.92
# ####################
# Confusion Matrix :
# [[126  12]
#  [  8 104]]
# ####################
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       138
#            1       0.90      0.93      0.91       112
#
#     accuracy                           0.92       250
#    macro avg       0.92      0.92      0.92       250
# weighted avg       0.92      0.92      0.92       250

# %% [markdown]
# <div style = 'background-color: #6482AD; text-align:center; padding: 10px; color:#F5EDED'>
#     <h2>Logistic Model With Multiclassification</h2>
# </div>

# %%
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=1000, n_features=10,n_informative=3 ,n_classes=3, random_state=42)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(multi_class='ovr')
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)
## Metrics Of Model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print(f'Accuracy = {accuracy_score(y_test, y_pred)}')
print('#'*20)
print('Confusion Matrix : ')
print(confusion_matrix(y_test, y_pred))
print('#'*20)
print('Classification Report : ')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy = 0.68
# ####################
# Confusion Matrix :
# [[79 16  8]
#  [31 38 27]
#  [ 3 11 87]]
# ####################
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.70      0.77      0.73       103
#            1       0.58      0.40      0.47        96
#            2       0.71      0.86      0.78       101
#
#     accuracy                           0.68       300
#    macro avg       0.67      0.67      0.66       300
# weighted avg       0.67      0.68      0.66       300

# %%
# Lets Try HyperParamter Tuning
from sklearn.model_selection import GridSearchCV, StratifiedKFold
parameters = {
    'penalty': ['l1', 'l2', 'elasticnet'],
    'C': [100, 10, 1.0, 0.1, 0.01],
    'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
}
grid = GridSearchCV(LogisticRegression(multi_class='ovr'), param_grid=parameters, cv = StratifiedKFold(), n_jobs=-1)
grid.fit(X_train, y_train)

## Metrics Of Model
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
y_pred = grid.predict(X_test)
print(f'Accuracy = {accuracy_score(y_test, y_pred)}')
print('#'*20)
print('Confusion Matrix : ')
print(confusion_matrix(y_test, y_pred))
print('#'*20)
print('Classification Report : ')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy = 0.6766666666666666
# ####################
# Confusion Matrix :
# [[81 13  9]
#  [36 32 28]
#  [ 2  9 90]]
# ####################
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73       103
#            1       0.59      0.33      0.43        96
#            2       0.71      0.89      0.79       101
#
#     accuracy                           0.68       300
#    macro avg       0.66      0.67      0.65       300
# weighted avg       0.66      0.68      0.65       300

# %%
grid.best_score_
# Out:
# 0.6385714285714286

# %%
grid.best_params_
# Out:
# {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}

# %% [markdown]
# <div style = 'background-color: #6482AD; text-align:center; padding: 10px; color:#F5EDED'>
#     <h2>Logistic Model With Imbalanced Data</h2>
# </div>

# %%
from collections import Counter
X, y = make_classification(n_samples=10000, n_features=2, n_clusters_per_class=1, n_redundant=0, weights=[0.99], random_state=10)

# %%
Counter(y)
# Out:
# Counter({0: 9846, 1: 154})

# %%
sns.scatterplot(x = pd.DataFrame(X)[0], y = pd.DataFrame(X)[1], hue = y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 10)

# %%
parameters = {
    'penalty': ['l1', 'l2', 'elasticnet'],
    'C': [100, 10, 1.0, 0.1, 0.01],
    'solver': ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'],
    'class_weight': [{0:w, 1:j} for w in [1, 10, 50, 100] for j in [1, 10, 50, 100]]
}
grid = GridSearchCV(LogisticRegression(), param_grid=parameters, cv = StratifiedKFold(), n_jobs=-1)
grid.fit(X_train, y_train)

y_pred = grid.predict(X_test)
print(f'Accuracy = {accuracy_score(y_test, y_pred)}')
print('#'*20)
print('Confusion Matrix : ')
print(confusion_matrix(y_test, y_pred))
print('#'*20)
print('Classification Report : ')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy = 0.9916
# ####################
# Confusion Matrix :
# [[2469    7]
#  [  14   10]]
# ####################
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2476
#            1       0.59      0.42      0.49        24
#
#     accuracy                           0.99      2500
#    macro avg       0.79      0.71      0.74      2500
# weighted avg       0.99      0.99      0.99      2500

# %%
grid.best_params_
# Out:
# {'C': 0.01, 'class_weight': {0: 10, 1: 50}, 'penalty': 'l2', 'solver': 'lbfgs'}

# %% [markdown]
# <div style = 'background-color: #6482AD; text-align:center; padding: 10px; color:#F5EDED'>
#     <h2>ROC Curve</h2>
# </div>

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
X, y = make_classification(n_samples=1000, n_classes=2, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
# Alwayes Predict Tho Output is 0
dummy_model_prob = [0 for _ in range(len(y_test))]

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# prediction based on probability
model_prob = model.predict_proba(X_test)

# %%
# Focus on the positive output
model_prob = model_prob[:, 1]

# %%
dummy_model_auc = roc_auc_score(y_test, dummy_model_prob)
model_auc = roc_auc_score(y_test, model_prob)
print(dummy_model_auc)
print(model_auc)
# Out:
# 0.5
# 0.9108885464817668

# %%
dummy_fpr, dummy_tpr,dummy_threshold = roc_curve(y_test, dummy_model_prob)
model_fpr, model_tpr, model_threshold = roc_curve(y_test, model_prob)

# %%
plt.plot(dummy_fpr, dummy_tpr, linestyle = '-', label = 'Dummy Model')
plt.plot(model_fpr, model_tpr, marker = '.', label = 'Logistic')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 50))

# Plotting ROC curves
ax.plot(dummy_fpr, dummy_tpr, linestyle='-', label='Dummy Model')
ax.plot(model_fpr, model_tpr, marker='.', label='Logistic')

# Annotating thresholds
for fpr, tpr, thresh in zip(model_fpr, model_tpr, model_threshold):
    ax.annotate(f'{thresh:.2f}', xy=(fpr, tpr), textcoords="offset points", xytext=(0, 10), ha='center')

# Adding labels and legend
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.legend()

plt.show()
